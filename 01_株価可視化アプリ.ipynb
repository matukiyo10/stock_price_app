# %%
# !pip3 install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\k\anaconda3\lib\site-packages (0.2.12)
# Requirement already satisfied: requests>=2.26 in c:\users\k\anaconda3\lib\site-packages (from yfinance) (2.27.1)
# Requirement already satisfied: html5lib>=1.1 in c:\users\k\anaconda3\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\k\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: cryptography>=3.3.2 in c:\users\k\anaconda3\lib\site-packages (from yfinance) (3.4.8)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\k\anaconda3\lib\site-packages (from yfinance) (4.9.2)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\k\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\k\anaconda3\lib\site-packages (from yfinance) (1.21.5)
# Requirement already satisfied: pytz>=2022.5 in c:\users\k\anaconda3\lib\site-packages (from yfinance) (2022.7.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\k\anaconda3\lib\site-packages (from yfinance) (2.3.5)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\k\anaconda3\lib\site-packages (from yfinance) (4.11.2)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\k\anaconda3\lib\site-packages (from yfinance) (1.4.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\k\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.1)
# Requirement already satisfied: cffi>=1.12 in c:\users\k\anaconda3\lib\site-packages (from cryptography>=3.3.2->yfinance) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\k\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance) (2.21)
# Requirement already satisfied: webencodings in c:\users\k\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: six>=1.9 in c:\users\k\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\k\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\k\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\k\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\k\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\k\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2022.6.15)
# WARNING: Ignoring invalid distribution -rotlipy (c:\users\k\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotlipy (c:\users\k\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotlipy (c:\users\k\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotlipy (c:\users\k\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotlipy (c:\users\k\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotlipy (c:\users\k\anaconda3\lib\site-packages)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import yfinance as yf

# %matplotlib inline

# %%
aapl = yf.Ticker('AAPL')

# %%
aapl

# %%
days = 20
hist = aapl.history(period=f'{days}d')
type(hist)

# %%
hist.columns

# %%
hist.reset_index()

# %%
hist_msft = yf.Ticker('MSFT').history(period=f'{days}d')
hist_msft.head()

# %%
pd.concat([hist, hist_msft], axis=1).head()

# %%
hist.head(3)

# %%
hist.index

# %%
hist.index = hist.index.strftime('%d %B %Y')

# %%
hist = hist[['Close']]
hist.columns = ['apple']
hist.head()

# %%
hist = hist.T

# %%
hist

# %%
hist.index.name = 'Name'

# %%
hist

# %%
days = 20
tickers = {
    'apple': 'AAPL',
    'facebook': 'META',
    'google': 'GOOGL',
    'maicrosoft': 'MSFT',
    'netflix': 'NFLX',
    'amazon': 'AMZN'
}

def get_data(days, tickers):
    df = pd.DataFrame()
    for company in tickers.keys():
        tkr = yf.Ticker(tickers[company])
        hist = tkr.history(period=f'{days}d')
        hist.index = hist.index.strftime('%d %B %Y')
        hist = hist[['Close']]
        hist.columns = [company]
        hist = hist.T
        hist.index.name = 'Name'
        df = pd.concat([df, hist])
    return df

# %%
df = get_data(days, tickers)

# %%
aapl = yf.Ticker('AAPL')

# %%
aapl.actions.head()
# Out:
#                            Dividends  Stock Splits
# Date
# 1987-05-11 00:00:00-04:00   0.000536           0.0
# 1987-06-16 00:00:00-04:00   0.000000           2.0
# 1987-08-10 00:00:00-04:00   0.000536           0.0
# 1987-11-17 00:00:00-05:00   0.000714           0.0
# 1988-02-12 00:00:00-05:00   0.000714           0.0

# %%
aapl.dividends.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
aapl.actions['Stock Splits'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# !pip install altair
# Out:
# Requirement already satisfied: altair in c:\users\k\anaconda3\lib\site-packages (4.2.2)
# Requirement already satisfied: numpy in c:\users\k\anaconda3\lib\site-packages (from altair) (1.21.5)
# Requirement already satisfied: entrypoints in c:\users\k\anaconda3\lib\site-packages (from altair) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\k\anaconda3\lib\site-packages (from altair) (4.4.0)
# Requirement already satisfied: toolz in c:\users\k\anaconda3\lib\site-packages (from altair) (0.11.2)
# Requirement already satisfied: pandas>=0.18 in c:\users\k\anaconda3\lib\site-packages (from altair) (1.4.2)
# Requirement already satisfied: jinja2 in c:\users\k\anaconda3\lib\site-packages (from altair) (2.11.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\k\anaconda3\lib\site-packages (from jsonschema>=3.0->altair) (22.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\k\anaconda3\lib\site-packages (from jsonschema>=3.0->altair) (0.18.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\k\anaconda3\lib\site-packages (from pandas>=0.18->altair) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\k\anaconda3\lib\site-packages (from pandas>=0.18->altair) (2022.7.1)
# Requirement already satisfied: six>=1.5 in c:\users\k\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.18->altair) (1.16.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\k\anaconda3\lib\site-packages (from jinja2->altair) (2.0.1)
# WARNING: Ignoring invalid distribution -rotlipy (c:\users\k\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotlipy (c:\users\k\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotlipy (c:\users\k\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotlipy (c:\users\k\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotlipy (c:\users\k\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotlipy (c:\users\k\anaconda3\lib\site-packages)

# %%
import altair as alt

# %%
df
# Out:
# Date        27 January 2023  30 January 2023  31 January 2023  \
# Name
# apple            145.707520       142.781998       144.070023
# facebook         151.740005       147.059998       148.970001
# google            99.370003        96.940002        98.839996
# maicrosoft       247.539993       242.103607       247.190857
# netflix          360.769989       353.109985       353.859985
# amazon           102.239998       100.550003       103.129997
#
# Date        01 February 2023  02 February 2023  03 February 2023  \
# Name
# apple             145.208282        150.590088        154.264465
# facebook          153.119995        188.770004        186.529999
# google            100.430000        107.739998        104.779999
# maicrosoft        252.118515        263.938904        257.704529
# netflix           361.989990        366.890015        365.899994
# amazon            105.150002        112.910004        103.389999
#
# Date        06 February 2023  07 February 2023  08 February 2023  \
# Name
# apple             151.498688        154.414230        151.688400
# facebook          186.059998        191.619995        183.429993
# google            102.900002        107.639999         99.370003
# maicrosoft        256.128448        266.891510        266.063599
# netflix           361.480011        362.950012        366.829987
# amazon            102.180000        102.110001        100.050003
#
# Date        09 February 2023  10 February 2023  13 February 2023  \
# Name
# apple             150.639999        151.009995        153.850006
# facebook          177.919998        174.149994        179.429993
# google             95.010002         94.570000         94.610001
# maicrosoft        262.961365        262.442657        270.642120
# netflix           362.500000        347.359985        358.570007
# amazon             98.239998         97.610001         99.540001
#
# Date        14 February 2023  15 February 2023  16 February 2023  \
# Name
# apple             153.199997        155.330002        153.710007
# facebook          179.479996        177.160004        172.440002
# google             94.680000         96.940002         95.510002
# maicrosoft        271.490021        269.320007        262.149994
# netflix           359.959991        361.420013        350.709991
# amazon             99.699997        101.160004         98.150002
#
# Date        17 February 2023  21 February 2023  22 February 2023  \
# Name
# apple             152.550003        148.479996        148.910004
# facebook          172.880005        172.080002        171.119995
# google             94.349998         91.790001         91.650002
# maicrosoft        258.059998        252.669998        251.509995
# netflix           347.959991        337.500000        334.880005
# amazon             97.199997         94.580002         95.790001
#
# Date        23 February 2023  24 February 2023
# Name
# apple             149.399994        146.710007
# facebook          172.039993        170.389999
# google             90.889999         89.129997
# maicrosoft        254.770004        249.220001
# netflix           323.649994        317.149994
# amazon             95.820000         93.500000

# %%
companies = ['apple', 'facebook']
data = df.loc[companies]
data
# Out:
# Date      30 January 2023  31 January 2023  01 February 2023  \
# Name
# apple          142.781998       144.070023        145.208282
# facebook       147.059998       148.970001        153.119995
#
# Date      02 February 2023  03 February 2023  06 February 2023  \
# Name
# apple           150.590088        154.264465        151.498688
# facebook        188.770004        186.529999        186.059998
#
# Date      07 February 2023  08 February 2023  09 February 2023  \
# Name
# apple           154.414230        151.688400        150.639999
# facebook        191.619995        183.429993        177.919998
#
# Date      10 February 2023  13 February 2023  14 February 2023  \
# Name
# apple           151.009995        153.850006        153.199997
# facebook        174.149994        179.429993        179.479996
#
# Date      15 February 2023  16 February 2023  17 February 2023  \
# Name
# apple           155.330002        153.710007        152.550003
# facebook        177.160004        172.440002        172.880005
#
# Date      21 February 2023  22 February 2023  23 February 2023  \
# Name
# apple           148.479996        148.910004        149.399994
# facebook        172.080002        171.119995        172.039993
#
# Date      24 February 2023  27 February 2023
# Name
# apple           146.710007        147.919998
# facebook        170.389999        169.539993

# %%
data.sort_index()
# Out:
# Date      30 January 2023  31 January 2023  01 February 2023  \
# Name
# apple          142.781998       144.070023        145.208282
# facebook       147.059998       148.970001        153.119995
#
# Date      02 February 2023  03 February 2023  06 February 2023  \
# Name
# apple           150.590088        154.264465        151.498688
# facebook        188.770004        186.529999        186.059998
#
# Date      07 February 2023  08 February 2023  09 February 2023  \
# Name
# apple           154.414230        151.688400        150.639999
# facebook        191.619995        183.429993        177.919998
#
# Date      10 February 2023  13 February 2023  14 February 2023  \
# Name
# apple           151.009995        153.850006        153.199997
# facebook        174.149994        179.429993        179.479996
#
# Date      15 February 2023  16 February 2023  17 February 2023  \
# Name
# apple           155.330002        153.710007        152.550003
# facebook        177.160004        172.440002        172.880005
#
# Date      21 February 2023  22 February 2023  23 February 2023  \
# Name
# apple           148.479996        148.910004        149.399994
# facebook        172.080002        171.119995        172.039993
#
# Date      24 February 2023  27 February 2023
# Name
# apple           146.710007        147.919998
# facebook        170.389999        169.539993

# %%
data = data.T.reset_index()
data.head()
# Out:
# Name              Date       apple    facebook
# 0      30 January 2023  142.781998  147.059998
# 1      31 January 2023  144.070023  148.970001
# 2     01 February 2023  145.208282  153.119995
# 3     02 February 2023  150.590088  188.770004
# 4     03 February 2023  154.264465  186.529999

# %%
data = pd.melt(data, id_vars=['Date']).rename(
    columns={'value': 'Stock Prices(USD)'}
)
data
# Out:
#                 Date      Name  Stock Prices(USD)
# 0    30 January 2023     apple         142.781998
# 1    31 January 2023     apple         144.070023
# 2   01 February 2023     apple         145.208282
# 3   02 February 2023     apple         150.590088
# 4   03 February 2023     apple         154.264465
# 5   06 February 2023     apple         151.498688
# 6   07 February 2023     apple         154.414230
# 7   08 February 2023     apple         151.688400
# 8   09 February 2023     apple         150.639999
# 9   10 February 2023     apple         151.009995
# 10  13 February 2023     apple         153.850006
# 11  14 February 2023     apple         153.199997
# 12  15 February 2023     apple         155.330002
# 13  16 February 2023     apple         153.710007
# 14  17 February 2023     apple         152.550003
# 15  21 February 2023     apple         148.479996
# 16  22 February 2023     apple         148.910004
# 17  23 February 2023     apple         149.399994
# 18  24 February 2023     apple         146.710007
# 19  27 February 2023     apple         147.919998
# 20   30 January 2023  facebook         147.059998
# 21   31 January 2023  facebook         148.970001
# 22  01 February 2023  facebook         153.119995
# 23  02 February 2023  facebook         188.770004
# 24  03 February 2023  facebook         186.529999
# 25  06 February 2023  facebook         186.059998
# 26  07 February 2023  facebook         191.619995
# 27  08 February 2023  facebook         183.429993
# 28  09 February 2023  facebook         177.919998
# 29  10 February 2023  facebook         174.149994
# 30  13 February 2023  facebook         179.429993
# 31  14 February 2023  facebook         179.479996
# 32  15 February 2023  facebook         177.160004
# 33  16 February 2023  facebook         172.440002
# 34  17 February 2023  facebook         172.880005
# 35  21 February 2023  facebook         172.080002
# 36  22 February 2023  facebook         171.119995
# 37  23 February 2023  facebook         172.039993
# 38  24 February 2023  facebook         170.389999
# 39  27 February 2023  facebook         169.539993
